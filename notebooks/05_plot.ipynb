# %%
import os
import numpy as np
import pandas as pd

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append(os.path.abspath(os.path.join('..')))

# %%
from paths import *
from utils import *

# %%
#features column names
#formant
formant_feat_col = ['F1', 'F2']

#MFCC
mfcc_feat_col = [f'mfcc{i}' for i in range(1, 14)]

# %% [markdown]
# ##### Plot Vowel space area for a particuar speaker of a particular age and Register for three corenr vowles

# %%
df_formant = pd.read_csv(r'C:\Users\arunps\OneDrive\Projects\Scripts\Python\NorwagianAndDanishIDSandADS\CenterFrameFeatures\formant_no_IDS_3_bordervowels_M.csv')

# %%
df_mfcc = pd.read_csv(r'C:\Users\arunps\OneDrive\Projects\Scripts\Python\NorwagianAndDanishIDSandADS\CenterFrameFeatures\mfcc_no_IDS_3_bordervowels_M.csv')

# %%
plot_convex_hull(df_formant, 'MIDS103', 12, formant_feat_col,3, feature_type='formant', save_dir=plot_dir)
# Out:
# Plot saved as c:\Users\arunps\OneDrive\Projects\Scripts\Python\NorwagianAndDanishIDSandADS\PlotVowelBasedMeasures\VowelSpaceArea_formant_3_MIDS103_12.pdf

# %%
plot_convex_hull(df_mfcc, 'MIDS103', 12, mfcc_feat_col, 3, feature_type='mfcc', save_dir=plot_dir)
# Out:
# Plot saved as c:\Users\arunps\OneDrive\Projects\Scripts\Python\NorwagianAndDanishIDSandADS\PlotVowelBasedMeasures\VowelSpaceArea_mfcc_3_MIDS103_12.pdf

# %% [markdown]
# ##### Plot for variability for a particuar speaker of a particular age and Register for three corenr vowles

# %%
plot_variability(df_formant, 'MIDS103', 12, formant_feat_col,3, feature_type='formant', save_dir=plot_dir)
# Out:
# c:\Users\arunps\OneDrive\Projects\Scripts\Python\NorwagianAndDanishIDSandADS\utils.py:234: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if feature_type == 'formant':
# c:\Users\arunps\OneDrive\Projects\Scripts\Python\NorwagianAndDanishIDSandADS\utils.py:234: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if feature_type == 'formant':
# ...

# %%
plot_variability(df_mfcc, 'MIDS103', 12, mfcc_feat_col,3, feature_type='mfcc', save_dir=plot_dir)
# Out:
# c:\Users\arunps\OneDrive\Projects\Scripts\Python\NorwagianAndDanishIDSandADS\utils.py:234: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if feature_type == 'formant':
# c:\Users\arunps\OneDrive\Projects\Scripts\Python\NorwagianAndDanishIDSandADS\utils.py:234: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if feature_type == 'formant':
# ...

# %% [markdown]
# ##### Plot for separability for a particuar speaker of a particular age and Register for three corenr vowles

# %%
plot_vowel_separability(df_formant, 'MIDS103', 12, formant_feat_col,3, feature_type='formant', save_dir=plot_dir)
# Out:
# Plot saved as c:\Users\arunps\OneDrive\Projects\Scripts\Python\NorwagianAndDanishIDSandADS\PlotVowelBasedMeasures\Separability_formant_3_MIDS103_12.pdf

# %%
plot_vowel_separability(df_mfcc, 'MIDS103', 12, mfcc_feat_col,3, feature_type='mfcc', save_dir=plot_dir)
# Out:
# Plot saved as c:\Users\arunps\OneDrive\Projects\Scripts\Python\NorwagianAndDanishIDSandADS\PlotVowelBasedMeasures\Separability_mfcc_3_MIDS103_12.pdf
